# %%
import os
import folium
import pandas as pd
import time
from geopy.geocoders import Nominatim
geolocator = Nominatim()

import pickle
def writePickle(var, filename):
    with open(filename, 'wb') as f:  # Python 3: open(..., 'wb')
        pickle.dump(var, f)
        return
 
def readPickle(filename):
    with open(filename, 'rb') as f:  # Python 3: open(..., 'rb')
        return pickle.load(f)

master = readPickle('data/master.pkl')
master= master[0]

def mat(st,ma):
    raw = st.split()
    ya=set(raw).intersection(set(ma))
    if(bool(ya)):
        geolocator = Nominatim()
        location = geolocator.geocode(ya)
        tup=(location.latitude,location.longitude)
        print(location)
        print(location.latitude)
        print(location.longitude)
        return tup,ya
    ya='Singapore'
    geolocator = Nominatim()
    location = geolocator.geocode(ya)
    tup=(location.latitude,location.longitude)
    print(location)
    print(location.latitude)
    print(location.longitude)
    return tup,ya

df=pd.read_csv('data/CSSol-2/whole_train.csv')
df=df[['ordering_customer','beneficiary']]
df=df.astype('str')
folium_map = folium.Map(location=[20, 10],
                        zoom_start=2.5,
                        tiles="CartoDB dark_matter")
for index, row in df.iterrows():
    print(row)
    fromTuple, fromCity=mat(str(row['ordering_customer'][0]),master)
    toTuple, toCity=mat(str(row['beneficiary'][0]),master)
    x1, y1 =  fromTuple
    x2, y2 = toTuple 
    folium.CircleMarker(location=[x1, y1],fill=True).add_to(folium_map)
    folium.CircleMarker(location=[x2, y2],fill=True).add_to(folium_map)
#     m = umap(fromCity,fromTuple,toCity,toTuple)
#     display(m)
#     time.sleep(2)
    if index >15:
        break
folium_map
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ordering_customer    /XXXXXXXXXXX\r\n\r\nALLIANZ WORLDWIDE CARE SA ...
# beneficiary                     /XXXXXXXXXXX\r\n\r\nSUBODH S. NADKARNI
# Name: 0, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nREEBONZ LIMITED\r\n\r\n5 T...
# beneficiary          /XXXXXXXXXXX\r\n\r\nTIZIANA FAUSTI SAGL\r\n\r\...
# Name: 1, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nQK MARINE SERVICES PVT LTD...
# beneficiary          /XXXXXXXXXXX\r\n\r\nPOET SHIPBUILDING AND\r\n\...
# Name: 2, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nAGODA COMPANY PTE LTD\r\n\...
# beneficiary          /XXXXXXXXXXX\r\n\r\nGINJUPALLI DEEPA\r\n\r\n40...
# Name: 3, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nKNOWLES ELECTRONICS (SUZHO...
# beneficiary            /XXXXXXXXXXX\r\n\r\nKULICKE AND SOFFA PTE. LTD.
# Name: 4, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nIG ASIA P L-CLIENTSA/C\r\n...
# beneficiary                         /XXXXXXXXXXX\r\n\r\nSai Choong Lee
# Name: 5, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nASCENDAS HOSPITALITY BT - ...
# beneficiary          /XXXXXXXXXXX\r\n\r\nDBS BANK LTD TREASUARY N M...
# Name: 6, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nGENOMAX TECHNOLOGIES PTE. ...
# beneficiary          /XXXXXXXXXXX\r\n\r\nAGILENT TECHNOLOGIES SINGA...
# Name: 7, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nRADIO HOLLAND SINGAPORE PT...
# beneficiary          /XXXXXXXXXXX\r\n\r\nNOAH AGENCIES N MARINE SER...
# Name: 8, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nREN YI\r\n\r\nBLK55, HALL ...
# beneficiary          /XXXXXXXXXXX\r\n\r\nLEE SUNG ON\r\n\r\n9TH FL....
# Name: 9, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    XXXXXXXXXXX\r\n\r\n1/ETARI PROPERTY PTE. LTD.\...
# beneficiary          /XXXXXXXXXXX\r\n\r\nCOMMISSIONER OF INLAND REV...
# Name: 10, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nUOB VISA CARD CENTRE-A/C 3...
# beneficiary          /XXXXXXXXXXX\r\n\r\nNAI KWANG HWA BENJAMIN\r\n...
# Name: 11, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nVODAFONE ENTERPRISE SINGAP...
# beneficiary          /XXXXXXXXXXX\r\n\r\nMADANKRISHNA CHAITANYA VYA...
# Name: 12, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nZHUANG HONGJU\r\n\r\nNO006...
# beneficiary          /XXXXXXXXXXX\r\n\r\nMANAGEMENT DEVELOPMENT INS...
# Name: 13, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nDSG CONSUMER PARTNERS II\r...
# beneficiary          /XXXXXXXXXXX\r\n\r\nDEEPAK ISHWARDAS SHAHDADPU...
# Name: 14, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nGUINAULT-LEBRUN SA\r\n\r\n...
# beneficiary                       /XXXXXXXXXXX\r\n\r\nCW SINGAPORE SGD
# Name: 15, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# ordering_customer    /XXXXXXXXXXX\r\n\r\nALVEO LAND CORP\r\n\r\n2F ...
# beneficiary          /XXXXXXXXXXX\r\n\r\nMARIE MONOZCA\r\n\r\nUNIT ...
# Name: 16, dtype: object
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
# Singapore, Central, 178957, Singapore
# 1.2904753
# 103.8520359
